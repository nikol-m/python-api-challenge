# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
import random

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file from the GitHub URL into a Pandas DataFrame
url = "https://raw.githubusercontent.com/nikol-m/python-api-challenge/main/cities.csv"
city_data_df = pd.read_csv(url)

# Display sample data
print(city_data_df.head())
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      pevek  69.7008  170.3133    278.74        88         100
# 1        1      avera  33.1940  -82.5271    298.18        52         100
# 2        2  grindavik  63.8424  -22.4338    287.41        72          75
# 3        3     albany  42.6001  -73.9662    303.47        69          43
# 4        4     barrow  71.2906 -156.7887    281.16        93         100
#
#    Wind Speed Country        Date
# 0        0.36      RU  1690650521
# 1        1.17      US  1690650522
# 2        4.63      IS  1690650522
# 3        0.45      US  1690650422
# 4        4.12      US  1690650523

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Create a map centered at a specific location (e.g., coordinates of the first city in the DataFrame)


# Define a function to map humidity values to colors
map_center = [city_data_df["Lat"].iloc[0], city_data_df["Lng"].iloc[0]]
mymap = folium.Map(location=map_center, zoom_start=5)

# Configure the map plot
def get_color(humidity):
    if humidity <= 30:
        return 'green'
    elif humidity <= 60:
        return 'blue'
    else:
        return 'pink'

# Iterate through the DataFrame and add a marker for each city with size and color based on humidity
for index, row in city_data_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    humidity = row["Humidity"]

    # Create a circle marker with size and color based on humidity
    folium.CircleMarker(
        location=[lat, lng],
        radius=humidity / 8,  
        popup=f"City: {row['City']}, Humidity: {humidity}",
        fill=True,
        fill_color=get_color(humidity),
        color='gray',
        fill_opacity=0.4
    ).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f30b9229114088f7b48a4525d89b0691 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f30b9229114088f7b48a4525d89b0691&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f30b9229114088f7b48a4525d89b0691 = L.map(
#                 &quot;map_f30b9229114088f7b48a4525d89b0691&quot;,
#                 {
#                     center: [69.7008, 170.3133],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bfa463b006b633305bccecbb67f882b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f30b9229114088f7b48a4525d89b0691);
#
#
#             var circle_marker_cb837e4f5b97b99d1983b93e8d23533d = L.circleMarker(
#                 [69.7008, 170.3133],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f30b9229114088f7b48a4525d89b0691);
#
#
#         var popup_9bf56fcfb3e5410aab5b7d5efd8d1538 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e46541b892fe986b50e1cc2b6df7091c = $(`&lt;div id=&quot;html_e46541b892fe986b50e1cc2b6df7091c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: pevek, Humidity: 88&lt;/div&gt;`)[0];
#                 popup_9bf56fcfb3e5410aab5b7d5efd8d1538.setContent(html_e46541b892fe986b50e1cc2b6df7091c);
#
#
#
#         circle_marker_cb837e4f5b97b99d1983b93e8d23533d.bindPopup(popup_9bf56fcfb3e5410aab5b7d5efd8d1538)
#         ;
#
#
#
#
#             var circle_marker_c5751f433ab532e866da2a1444725bc2 = L.circleMarker(
#                 [33.194, -82.5271],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f30b9229114088f7b48a4525d89b0691);
#
#
#         var popup_df2eabd764ce98cfe837322a9a51f67b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3049664265e7014eceebab108e1bcbf7 = $(`&lt;div id=&quot;html_3049664265e7014eceebab108e1bcbf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: avera, Humidity: 52&lt;/div&gt;`)[0];
#                 popup_df2eabd764ce98cfe837322a9a51f67b.setContent(html_3049664265e7014eceebab108e1bcbf7);
#
#
#
#         circle_marker_c5751f433ab532e866da2a1444725bc2.bindPopup(popup_df2eabd764ce98cfe837322a9a51f67b)
#         ;
#
#
#
#
#             var circle_marker_28b397cfbc7250e8f1c2663c363ea1a7 = L.circleMarker(
#                 [63.8424, -22.4338],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f30b9229114088f7b48a4525d89b0691);
#
#
#         var popup_13881a5ede4d11b298f68df7d4b2a420 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4530cdb2194d93310fd974a41c2a6288 = $(`&lt;div id=&quot;html_4530cdb2194d93310fd974a41c2a6288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: grindavik, Humidity: 72&lt;/div&gt;`)[0];
#                 popup_13881a5ede4d11b298f68df7d4b2a420.setContent(html_4530cdb2194d93310fd974a41c2a6288);
#
#
#
#         circle_marker_28b397cfbc7250e8f1c2663c363ea1a7.bindPopup(popup_13881a5ede4d11b298f68df7d4b2a420)
#         ;
#
#
#
#
#             var circle_marker_f2c48d30a1fcd92e5435b2b931b3d128 = L.circleMarker(
#                 [42.6001, -73.9662],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: n

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filtered_cities = city_data_df[(city_data_df['Max Temp'] > 20) & (city_data_df['Humidity'] < 80) & (city_data_df['Cloudiness'] == 0)]

# Drop any rows with null values
filtered_cities = filtered_cities.dropna()

# Display sample data
filtered_cities.head(20)
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 26        26   ponta do sol  32.6667  -17.1000    300.50        71
# 31        31      carnarvon -24.8667  113.6333    289.78        69
# 48        48       bardiyah  31.7561   25.0865    300.30        69
# 101      101          ceres  37.5949 -120.9577    303.33        27
# 111      111   saint george  37.1041 -113.5841    308.94        25
# 114      114         tiznit  29.5833   -9.5000    304.23        37
# 117      117       acapulco  16.8634  -99.8901    305.05        58
# 151      151        luangwa -15.6167   30.4167    295.97        42
# 154      154         broome  42.2506  -75.8330    300.94        78
# 162      162    east london -33.0153   27.9116    289.67        67
# 163      163         beloha -25.1667   45.0500    291.08        78
# 176      176     swan river  52.1058 -101.2676    294.09        56
# 177      177         laguna  38.4210 -121.4238    303.16        44
# 204      204    zhanakorgan  43.9098   67.2495    304.96        17
# 206      206         nurota  40.5614   65.6886    303.40        15
# 209      209  mar del plata -38.0023  -57.5575    288.12        70
# 211      211         talara  -4.5772  -81.2719    301.57        61
# 220      220        corinth  37.9407   22.9573    303.09        46
# 222      222        baghdad  33.3406   44.4009    312.10        17
# 232      232          suluq  31.6682   20.2521    303.26        43
#
#      Cloudiness  Wind Speed Country        Date
# 26            0        0.83      PT  1690650540
# 31            0        6.72      AU  1690650542
# 48            0        9.02      LY  1690650555
# 101           0        2.57      US  1690650613
# 111           0        3.09      US  1690650619
# 114           0        3.64      MA  1690650621
# 117           0        4.12      MX  1690650623
# 151           0        1.53      ZM  1690650645
# 154           0        4.12      US  1690650647
# 162           0        3.60      ZA  1690650651
# 163           0        1.86      MG  1690650652
# 176           0        3.60      CA  1690650663
# 177           0        4.12      US  1690650664
# 204           0        4.56      KZ  1690650681
# 206           0        4.27      UZ  1690650682
# 209           0       10.29      AR  1690650637
# 211           0        7.20      PE  1690650684
# 220           0        1.14      GR  1690650688
# 222           0        2.57      IQ  1690650689
# 232           0        7.84      LY  1690650693

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_cities.copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head(20)
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 26        26   ponta do sol  32.6667  -17.1000    300.50        71
# 31        31      carnarvon -24.8667  113.6333    289.78        69
# 48        48       bardiyah  31.7561   25.0865    300.30        69
# 101      101          ceres  37.5949 -120.9577    303.33        27
# 111      111   saint george  37.1041 -113.5841    308.94        25
# 114      114         tiznit  29.5833   -9.5000    304.23        37
# 117      117       acapulco  16.8634  -99.8901    305.05        58
# 151      151        luangwa -15.6167   30.4167    295.97        42
# 154      154         broome  42.2506  -75.8330    300.94        78
# 162      162    east london -33.0153   27.9116    289.67        67
# 163      163         beloha -25.1667   45.0500    291.08        78
# 176      176     swan river  52.1058 -101.2676    294.09        56
# 177      177         laguna  38.4210 -121.4238    303.16        44
# 204      204    zhanakorgan  43.9098   67.2495    304.96        17
# 206      206         nurota  40.5614   65.6886    303.40        15
# 209      209  mar del plata -38.0023  -57.5575    288.12        70
# 211      211         talara  -4.5772  -81.2719    301.57        61
# 220      220        corinth  37.9407   22.9573    303.09        46
# 222      222        baghdad  33.3406   44.4009    312.10        17
# 232      232          suluq  31.6682   20.2521    303.26        43
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 26            0        0.83      PT  1690650540
# 31            0        6.72      AU  1690650542
# 48            0        9.02      LY  1690650555
# 101           0        2.57      US  1690650613
# 111           0        3.09      US  1690650619
# 114           0        3.64      MA  1690650621
# 117           0        4.12      MX  1690650623
# 151           0        1.53      ZM  1690650645
# 154           0        4.12      US  1690650647
# 162           0        3.60      ZA  1690650651
# 163           0        1.86      MG  1690650652
# 176           0        3.60      CA  1690650663
# 177           0        4.12      US  1690650664
# 204           0        4.56      KZ  1690650681
# 206           0        4.27      UZ  1690650682
# 209           0       10.29      AR  1690650637
# 211           0        7.20      PE  1690650684
# 220           0        1.14      GR  1690650688
# 222           0        2.57      IQ  1690650689
# 232           0        7.84      LY  1690650693

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Assume you already have the hotel_df DataFrame created with columns "City", "Country", "Lat", and "Lng"

# Set the API key and other parameters
api_key = "3092a0917c0247e9800baef5180c702a"
base_url = "https://api.geoapify.com/v2/places"
categories = "accommodation.hotel"

# Function to get the nearest hotel for a given set of coordinates
def get_nearest_hotel(lat, lng):
    # Construct the API request URL with the provided coordinates
    url = f"{base_url}?categories={categories}&apiKey={api_key}&lat={lat}&lon={lng}"

    # Make the API request
    response = requests.get(url)

    # Check the API response
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()

        # Get the first hotel from the response (nearest one)
        feature = data.get("features", [])[0]
        properties = feature.get("properties", {})
        hotel_name = properties.get("name", "Unknown")

        return hotel_name
    else:
        # Handle the error
        print(f"Error: {response.json()}")
        return "No hotel found"


# Use the Pandas apply function to add the "Hotel Name" for each row in the DataFrame
hotel_df["Hotel Name"] = hotel_df.apply(lambda row: get_nearest_hotel(row["Lat"], row["Lng"]), axis=1)


# Display the DataFrame with the hotel information
print("hotel_df")

# Display sample data
hotel_df.head(20)
# Out:
# hotel_df
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 26        26   ponta do sol  32.6667  -17.1000    300.50        71
# 31        31      carnarvon -24.8667  113.6333    289.78        69
# 48        48       bardiyah  31.7561   25.0865    300.30        69
# 101      101          ceres  37.5949 -120.9577    303.33        27
# 111      111   saint george  37.1041 -113.5841    308.94        25
# 114      114         tiznit  29.5833   -9.5000    304.23        37
# 117      117       acapulco  16.8634  -99.8901    305.05        58
# 151      151        luangwa -15.6167   30.4167    295.97        42
# 154      154         broome  42.2506  -75.8330    300.94        78
# 162      162    east london -33.0153   27.9116    289.67        67
# 163      163         beloha -25.1667   45.0500    291.08        78
# 176      176     swan river  52.1058 -101.2676    294.09        56
# 177      177         laguna  38.4210 -121.4238    303.16        44
# 204      204    zhanakorgan  43.9098   67.2495    304.96        17
# 206      206         nurota  40.5614   65.6886    303.40        15
# 209      209  mar del plata -38.0023  -57.5575    288.12        70
# 211      211         talara  -4.5772  -81.2719    301.57        61
# 220      220        corinth  37.9407   22.9573    303.09        46
# 222      222        baghdad  33.3406   44.4009    312.10        17
# 232      232          suluq  31.6682   20.2521    303.26        43
#
#      Cloudiness  Wind Speed Country        Date  \
# 26            0        0.83      PT  1690650540
# 31            0        6.72      AU  1690650542
# 48            0        9.02      LY  1690650555
# 101           0        2.57      US  1690650613
# 111           0        3.09      US  1690650619
# 114           0        3.64      MA  1690650621
# 117           0        4.12      MX  1690650623
# 151           0        1.53      ZM  1690650645
# 154           0        4.12      US  1690650647
# 162           0        3.60      ZA  1690650651
# 163           0        1.86      MG  1690650652
# 176           0        3.60      CA  1690650663
# 177           0        4.12      US  1690650664
# 204           0        4.56      KZ  1690650681
# 206           0        4.27      UZ  1690650682
# 209           0       10.29      AR  1690650637
# 211           0        7.20      PE  1690650684
# 220           0        1.14      GR  1690650688
# 222           0        2.57      IQ  1690650689
# 232           0        7.84      LY  1690650693
#
#                                       Hotel Name
# 26                        Estalagem Ponta do Sol
# 31                     Monkey Mia Dolphin Resort
# 48                                   فندق البردي
# 101      Howard Johnson by Wyndham Modesto Ceres
# 111  The Advenire, an Autograph Collection Hotel
# 114                                      Kerdous
# 117                              Hotel del Valle
# 151                       Redcliff Zambezi Lodge
# 154                         Quality Inn & Suites
# 162                                      Unknown
# 163                                   Hôtel Oliv
# 176                           Swan River Super 8
# 177                 Holiday Inn Express & Suites
# 204                                        Мейир
# 206                                       Nurota
# 209                                Nuevo Ostende
# 211                          Hospedaje El Aypate
# 220                                      Apollon
# 222                               AL Bedaa Hotel
# 232                            فندق منارة بنغازي

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
# Create a map centered at a specific location (e.g., coordinates of the first city in the DataFrame)
map_center = [hotel_df["Lat"].iloc[0], hotel_df["Lng"].iloc[0]]
mymap = folium.Map(location=map_center, zoom_start=5)

# Create a dictionary to map each unique city to a color
city_to_color = {}

# Function to get a unique color for each city
def get_color(city):
    if city not in city_to_color:
        random.seed(city)  # Seed the random number generator with the city name
        color = "#{:02x}{:02x}{:02x}".format(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
        city_to_color[city] = color
    return city_to_color[city]

# Iterate through the DataFrame and add a marker for each city with the hotel name in the popup
for index, row in hotel_df.head(20).iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    hotel_name = row["Hotel Name"]
    city_name = row["City"]
    country_name = row["Country"]

    # Create a circle marker with a unique color for each city
    folium.CircleMarker(
        location=[lat, lng],
        radius=5,
        popup=f"City: {city_name}, Country: {country_name}<br>Hotel: {hotel_name}",
        fill=True,
        fill_color=get_color(city_name),
        color='gray',
        fill_opacity=0.6
    ).add_to(mymap)

# Add the key on the right with each city and its corresponding color
key_html = '<div style="position: fixed; bottom: 50px; right: 50px; z-index: 1000; background-color: white; padding: 10px; border: 1px solid gray;">'
for city, color in city_to_color.items():
    key_html += f'<div style="display: flex; align-items: center;"><div style="width: 15px; height: 15px; background-color: {color}; margin-right: 5px;"></div>{city}</div>'
key_html += '</div>'

mymap.get_root().html.add_child(folium.Element(key_html))

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13d9841f0c5f3f29d8e550998b254fa3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; right: 50px; z-index: 1000; background-color: white; padding: 10px; border: 1px solid gray;&quot;&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #f941cc; margin-right: 5px;&quot;&gt;&lt;/div&gt;ponta do sol&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #4d1601; margin-right: 5px;&quot;&gt;&lt;/div&gt;carnarvon&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #d0af6a; margin-right: 5px;&quot;&gt;&lt;/div&gt;bardiyah&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #98948e; margin-right: 5px;&quot;&gt;&lt;/div&gt;ceres&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #003e5e; margin-right: 5px;&quot;&gt;&lt;/div&gt;saint george&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #546073; margin-right: 5px;&quot;&gt;&lt;/div&gt;tiznit&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #657b57; margin-right: 5px;&quot;&gt;&lt;/div&gt;acapulco&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #461fcd; margin-right: 5px;&quot;&gt;&lt;/div&gt;luangwa&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #25a247; margin-right: 5px;&quot;&gt;&lt;/div&gt;broome&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #02c71d; margin-right: 5px;&quot;&gt;&lt;/div&gt;east london&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #3ca7ea; margin-right: 5px;&quot;&gt;&lt;/div&gt;beloha&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #747489; margin-right: 5px;&quot;&gt;&lt;/div&gt;swan river&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #d706e2; margin-right: 5px;&quot;&gt;&lt;/div&gt;laguna&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #ee4bc6; margin-right: 5px;&quot;&gt;&lt;/div&gt;zhanakorgan&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #34d093; margin-right: 5px;&quot;&gt;&lt;/div&gt;nurota&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #3a333c; margin-right: 5px;&quot;&gt;&lt;/div&gt;mar del plata&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #f2addf; margin-right: 5px;&quot;&gt;&lt;/div&gt;talara&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #896132; margin-right: 5px;&quot;&gt;&lt;/div&gt;corinth&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quot;&gt;&lt;div style=&quot;width: 15px; height: 15px; background-color: #be3961; margin-right: 5px;&quot;&gt;&lt;/div&gt;baghdad&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center;&quo ...
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13d9841f0c5f3f29d8e550998b254fa3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13d9841f0c5f3f29d8e550998b254fa3 = L.map(
#                 &quot;map_13d9841f0c5f3f29d8e550998b254fa3&quot;,
#                 {
#                     center: [32.6667, -17.1],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f686813c1070897d4207d9411b2df93 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).
